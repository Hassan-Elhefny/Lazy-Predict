# %% [markdown]
# ***
# # Install and Import Library
# ***

# %%
# !pip install lazypredict
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting lazypredict
#   Downloading lazypredict-0.2.12-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from lazypredict) (1.2.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from lazypredict) (1.3.5)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from lazypredict) (7.1.2)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.8/dist-packages (from lazypredict) (2.2.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from lazypredict) (1.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from lazypredict) (4.64.1)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.8/dist-packages (from lazypredict) (0.90)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from lightgbm->lazypredict) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from lightgbm->lazypredict) (1.7.3)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->lazypredict) (2022.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->lazypredict) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->lazypredict) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->lazypredict) (1.15.0)
# Installing collected packages: lazypredict
# Successfully installed lazypredict-0.2.12

# %%
from lazypredict.Supervised import LazyClassifier, LazyRegressor
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_breast_cancer, load_boston
from sklearn.utils import shuffle
import numpy as np

# %% [markdown]
# ***
# # Classification
# ***

# %% [markdown]
# ## Load Breast Cancer Dataset

# %%
data = load_breast_cancer()
X = data.data
y= data.target

# %% [markdown]
# ## Split data to 70% train and 30% test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=42)

# %% [markdown]
# ## Chosse the best classification model

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models, predictions = clf.fit(X_train, X_test, y_train, y_test)
# Out:
# 100%|██████████| 29/29 [00:01<00:00, 14.93it/s]

# %%
models
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LogisticRegression                 0.98               0.98     0.98      0.98
# Perceptron                         0.98               0.98     0.98      0.98
# LinearSVC                          0.98               0.98     0.98      0.98
# SVC                                0.98               0.97     0.97      0.98
# PassiveAggressiveClassifier        0.98               0.97     0.97      0.98
# AdaBoostClassifier                 0.98               0.97     0.97      0.98
# ExtraTreesClassifier               0.98               0.97     0.97      0.98
# CalibratedClassifierCV             0.98               0.97     0.97      0.98
# SGDClassifier                      0.96               0.97     0.97      0.97
# RandomForestClassifier             0.97               0.96     0.96      0.97
# BernoulliNB                        0.96               0.96     0.96      0.96
# QuadraticDiscriminantAnalysis      0.96               0.96     0.96      0.96
# XGBClassifier                      0.96               0.96     0.96      0.96
# KNeighborsClassifier               0.96               0.95     0.95      0.96
# LGBMClassifier                     0.95               0.95     0.95      0.95
# BaggingClassifier                  0.95               0.95     0.95      0.95
# DecisionTreeClassifier             0.94               0.94     0.94      0.94
# RidgeClassifierCV                  0.95               0.94     0.94      0.95
# LinearDiscriminantAnalysis         0.95               0.94     0.94      0.95
# RidgeClassifier                    0.95               0.94     0.94      0.95
# LabelPropagation                   0.94               0.94     0.94      0.94
# LabelSpreading                     0.94               0.94     0.94      0.94
# NuSVC                              0.94               0.93     0.93      0.94
# GaussianNB                         0.94               0.93     0.93      0.94
# NearestCentroid                    0.94               0.93     0.93      0.94
# ExtraTreeClassifier                0.89               0.90     0.90      0.90
# DummyClassifier                    0.63               0.50     0.50      0.49
#
#                                Time Taken
# Model
# LogisticRegression                   0.04
# Perceptron                           0.02
# LinearSVC                            0.05
# SVC                                  0.05
# PassiveAggressiveClassifier          0.02
# AdaBoostClassifier                   0.45
# ExtraTreesClassifier                 0.13
# CalibratedClassifierCV               0.05
# SGDClassifier                        0.04
# RandomForestClassifier               0.23
# BernoulliNB                          0.02
# QuadraticDiscriminantAnalysis        0.03
# XGBClassifier                        0.22
# KNeighborsClassifier                 0.02
# LGBMClassifier                       0.17
# BaggingClassifier                    0.07
# DecisionTreeClassifier               0.02
# RidgeClassifierCV                    0.03
# LinearDiscriminantAnalysis           0.05
# RidgeClassifier                      0.02
# LabelPropagation                     0.03
# LabelSpreading                       0.03
# NuSVC                                0.04
# GaussianNB                           0.02
# NearestCentroid                      0.02
# ExtraTreeClassifier                  0.02
# DummyClassifier                      0.01

# %% [markdown]
# ***
# # Regression
# ***

# %% [markdown]
# ## Load Boston Dataset

# %%
boston = load_boston()
X, y = shuffle(boston.data, boston.target, random_state=13)
X = X.astype(np.float32)

# %% [markdown]
# ## Split data to 70% train and 30% test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=42)

# %% [markdown]
# ## Choose the best Regression Model

# %%
reg = LazyRegressor(verbose=0, ignore_warnings=True, custom_metric=None)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
# Out:
# 100%|██████████| 42/42 [00:04<00:00,  9.15it/s]
# [13:12:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
models
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# XGBRegressor                                 0.85       0.86  3.72        0.05
# GradientBoostingRegressor                    0.84       0.86  3.81        0.20
# ExtraTreesRegressor                          0.84       0.85  3.88        0.19
# HistGradientBoostingRegressor                0.83       0.85  3.95        0.22
# RandomForestRegressor                        0.82       0.84  4.06        0.33
# LGBMRegressor                                0.81       0.83  4.14        0.06
# BaggingRegressor                             0.78       0.80  4.52        0.05
# AdaBoostRegressor                            0.75       0.77  4.77        0.11
# PoissonRegressor                             0.73       0.75  5.03        0.02
# ExtraTreeRegressor                           0.68       0.71  5.39        0.01
# TransformedTargetRegressor                   0.67       0.70  5.50        0.01
# LinearRegression                             0.67       0.70  5.50        0.01
# Lars                                         0.67       0.70  5.50        0.04
# SGDRegressor                                 0.67       0.70  5.50        0.01
# Ridge                                        0.67       0.70  5.50        0.01
# RidgeCV                                      0.67       0.70  5.50        0.01
# LassoLarsIC                                  0.67       0.70  5.50        0.01
# LassoLarsCV                                  0.67       0.70  5.51        0.04
# BayesianRidge                                0.67       0.70  5.51        0.01
# KNeighborsRegressor                          0.66       0.69  5.56        0.02
# DecisionTreeRegressor                        0.66       0.69  5.63        0.01
# HuberRegressor                               0.64       0.67  5.74        0.03
# OrthogonalMatchingPursuitCV                  0.63       0.66  5.82        0.03
# LarsCV                                       0.63       0.66  5.88        0.07
# MLPRegressor                                 0.62       0.66  5.88        0.55
# LinearSVR                                    0.62       0.65  5.92        0.02
# SVR                                          0.60       0.64  6.04        0.02
# Lasso                                        0.60       0.63  6.07        0.02
# NuSVR                                        0.58       0.61  6.23        0.04
# ElasticNet                                   0.56       0.60  6.37        0.01
# TweedieRegressor                             0.54       0.58  6.54        0.02
# GammaRegressor                               0.53       0.57  6.57        0.01
# OrthogonalMatchingPursuit                    0.47       0.51  7.01        0.02
# RANSACRegressor                              0.42       0.47  7.34        0.14
# GaussianProcessRegressor                     0.25       0.31  8.34        0.04
# PassiveAggressiveRegressor                   0.22       0.28  8.50        0.02
# LassoLars                                   -0.09      -0.00 10.04        0.01
# DummyRegressor                              -0.09      -0.00 10.04        0.01
# QuantileRegressor                           -0.10      -0.01 10.08        1.99
# KernelRidge                                 -5.32      -4.77 24.12        0.03
